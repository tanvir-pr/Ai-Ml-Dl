# %% [markdown]
# # Reinforcement Learning Introduction
#
# ## Overview
# - Agent, Environment, Reward
# - Q-learning
# - Policy gradients
# - OpenAI Gym
#
# **Time:** 1-2 hours

# %%
# RL: Agent takes actions in environment, receives rewards
# Goal: Maximize cumulative reward

# Q-learning: Q(s,a) = expected future reward for action a in state s
# Update: Q(s,a) <- Q(s,a) + lr * (r + gamma * max Q(s',a') - Q(s,a))

# pip install gym
# import gym
# env = gym.make('CartPole-v1')
# obs = env.reset()
# action = env.action_space.sample()
# obs, reward, done, info = env.step(action)

print('RL: Agent learns policy through trial and error')
