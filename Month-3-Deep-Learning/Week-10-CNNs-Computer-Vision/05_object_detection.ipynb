# %% [markdown]
# # Object Detection Basics
#
# ## Overview
# - YOLO, R-CNN intro
# - Bounding boxes
# - Detection vs classification
#
# **Time:** 1-2 hours

# %%
# Object detection typically uses specialized libraries
# - tensorflow-hub: pretrained models
# - ultralytics (YOLOv8)
# - detectron2 (Facebook)

# Simple intro: understand the task
# Input: image -> Output: list of (class, bbox, confidence)
# bbox = [x, y, width, height] or [x1, y1, x2, y2]

print('Object detection outputs: bounding boxes + class labels')
