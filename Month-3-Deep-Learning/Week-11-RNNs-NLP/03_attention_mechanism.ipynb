# %% [markdown]
# # Attention Mechanism
#
# ## Overview
# - Attention: focus on relevant parts
# - Self-attention
# - Query, Key, Value
# - Basis for Transformers
#
# **Time:** 1-2 hours

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Multi-head attention in Keras
attn = layers.MultiHeadAttention(num_heads=4, key_dim=8)
# Input: (batch, seq_len, dim)
# Output: (batch, seq_len, dim)

# Self-attention: Q=K=V from same input
# Cross-attention: Q from one, K,V from another

print('Attention enables focusing on relevant tokens')
